# %% [markdown]
# # 파이토치
# * 파이토이를 사용할 때 반드시 알아야 할 요소

# %% [markdown]
# ## 텐서
# * 텐서란 :  데이터를 표현하는 단위
# * 스칼라 : 상수값, 즉 하나의 값을 표현할 때 1개의 수치로 표현한 것
#
# #### * 텐서 메서드를 이용해 스칼라 값을 정의 할 수 있음

# %%
import torch

# %%
scalar1 = torch.tensor([1.])
print (scalar1)
# Out:
# tensor([1.])

# %%
scalar2 = torch.tensor([3])
print (scalar2)
# Out:
# tensor([3])

# %%
add_scalar = scalar1 + scalar2
print (add_scalar)
# Out:
# tensor([4.])

# %%
sub_scalar = scalar1 - scalar2
print (sub_scalar)
# Out:
# tensor([-2.])

# %%
mul_scalar = scalar1 * scalar2
print (mul_scalar)
# Out:
# tensor([3.])

# %%
div_scalar = scalar1 / scalar2
print (div_scalar)
# Out:
# tensor([0.3333])

# %% [markdown]
# #### * 스칼라 값 간의 사칙연사 역시 torch 모듈에 내장된 메서드를 통해 계산할 수 있음

# %%
torch.add(scalar1, scalar2)
# Out:
# tensor([4.])

# %%
torch.sub(scalar1, scalar2)
# Out:
# tensor([-2.])

# %%
torch.mul(scalar1, scalar2)
# Out:
# tensor([3.])

# %%
torch.div(scalar1, scalar2)
# Out:
# tensor([0.3333])

# %% [markdown]
# ## Vector
# * 벡터는 하나의 값을 표현할 때 2개 이상의 수치로 표현한 것
# * 스칼라의 형태와 동일한 속성을 갖고 있지만, 여러 수치 값을 이용해 표현하는 방식

# %%
vector1 = torch.tensor([1., 2., 3.])
print (vector1)
# Out:
# tensor([1., 2., 3.])

# %%
vector2 = torch.tensor([4., 5, 6])
print (vector1)
# Out:
# tensor([1., 2., 3.])

# %% [markdown]
# * 벡터 값 간 사칙연산을 수행
#     * 사칙연산은 +, -, *, /를 이용해 계산할 수 있음
#     * 스칼라 사칙연산과 동일한 방식
#     * 각 요소별로 연산(elementwise)

# %%
add_vector = vector1 + vector2
print(add_vector)
# Out:
# tensor([5., 7., 9.])

# %%
sub_vector = vector1 - vector2
print(sub_vector)
# Out:
# tensor([-3., -3., -3.])

# %%
mul_vector = vector1 * vector2
print(mul_vector)
# Out:
# tensor([ 4., 10., 18.])

# %%
div_vector = vector1 / vector2
print(div_vector)
# Out:
# tensor([0.2500, 0.4000, 0.5000])

# %% [markdown]
# * 벡터 값 간 사칙연산 역시 torch 모듈에 내장된 메서드를 이용해 계산 할 수 있음
# * 벡터 값 간 내적 연산 역시 torch 모듈에 내장돼 사용할 수 있음

# %%
torch.add(vector1, vector2)
# Out:
# tensor([5., 7., 9.])

# %%
torch.sub(vector1, vector2)
# Out:
# tensor([-3., -3., -3.])

# %%
torch.mul(vector1, vector2)
# Out:
# tensor([ 4., 10., 18.])

# %%
torch.div(vector1, vector2)
# Out:
# tensor([0.2500, 0.4000, 0.5000])

# %%
vector1
# Out:
# tensor([1., 2., 3.])

# %%
vector2
# Out:
# tensor([4., 5., 6.])

# %%
torch.dot(vector1, vector2)
# Out:
# tensor(32.)

# %% [markdown]
# ### 행렬
# * 행렬(matrix)은 2개 이상의 벡터 값을 통합해 구성된 값으로, 벡터 값 간 연산속도를 빠르게 진행할 수 있는 선형 대수의 기본 단위임

# %%
matrix1 = torch.tensor([[1., 2.], [3., 4.]])
print(matrix1)
# Out:
# tensor([[1., 2.],
#         [3., 4.]])

# %%
matrix2 = torch.tensor([[5., 6.], [7., 8.]])
print(matrix2)
# Out:
# tensor([[5., 6.],
#         [7., 8.]])

# %%
sum_matrix = matrix1 + matrix2
print(sum_matrix)
# Out:
# tensor([[ 6.,  8.],
#         [10., 12.]])

# %%
sub_matrix = matrix1 - matrix2
print(sub_matrix)
# Out:
# tensor([[-4., -4.],
#         [-4., -4.]])

# %%
mul_matrix = matrix1 * matrix2
print(mul_matrix)
# Out:
# tensor([[ 5., 12.],
#         [21., 32.]])

# %%
div_matrix = matrix1 / matrix2
print(div_matrix)
# Out:
# tensor([[0.2000, 0.3333],
#         [0.4286, 0.5000]])

# %% [markdown]
# * 행렬 값 간 사칙연산 역시 torch 모듈에 내장된 메서드를 이용해 계산할 수 있음
# * 행렬 값 간의 내적 연산 역시 torch 모듈에 내장해 사용할 수 있음
# * 행렬 곱 연산은 torch.matmul을 이용해 실행할 수 있음

# %%
torch.add(matrix1, matrix2)
# Out:
# tensor([[ 6.,  8.],
#         [10., 12.]])

# %%
torch.sub(matrix1, matrix2)
# Out:
# tensor([[-4., -4.],
#         [-4., -4.]])

# %%
torch.mul(matrix1, matrix2)
# Out:
# tensor([[ 5., 12.],
#         [21., 32.]])

# %%
torch.div(matrix1, matrix2)
# Out:
# tensor([[0.2000, 0.3333],
#         [0.4286, 0.5000]])

# %%
torch.matmul(matrix1, matrix2)
# Out:
# tensor([[19., 22.],
#         [43., 50.]])

# %% [markdown]
# ## 텐서
# * 행렬을 2차원의 배열이라고 표현할 수 있다면, 텐서는 2차원 이상의 배열이라 표현할 수 있음
# -----------
# ![image.png](attachment:8d343dca-91e5-4c63-8509-91b080174fcc.png)
# --------
# * 텐서의 파이토치 예제 역시 스칼라 벡터, 행렬과 같은 논리로 적용
# * 텐서 내 행렬 단위의 인덱스 간, 행렬 내 인덱스 간 원소끼리 계산되며 행렬 곱은 텐서 내 같은 행렬 단위의 인덱스간에 계산

# %%
tensor1 = torch.tensor([[[1., 2.], [3., 4.]], [[5., 6.], [7., 8.]]])
print(tensor1)
# Out:
# tensor([[[1., 2.],
#          [3., 4.]],
#
#         [[5., 6.],
#          [7., 8.]]])

# %%
tensor2 = torch.tensor([[[9., 10.], [11., 12.]], [[13., 14.], [15., 16.]]])
print(tensor2)
# Out:
# tensor([[[ 9., 10.],
#          [11., 12.]],
#
#         [[13., 14.],
#          [15., 16.]]])

# %%
sum_tensor = tensor1 + tensor2
print(sum_tensor)
# Out:
# tensor([[[10., 12.],
#          [14., 16.]],
#
#         [[18., 20.],
#          [22., 24.]]])

# %%
sub_tensor = tensor1 - tensor2
print(sub_tensor)
# Out:
# tensor([[[-8., -8.],
#          [-8., -8.]],
#
#         [[-8., -8.],
#          [-8., -8.]]])

# %%
mul_tensor = tensor1 * tensor2
print(mul_tensor)
# Out:
# tensor([[[  9.,  20.],
#          [ 33.,  48.]],
#
#         [[ 65.,  84.],
#          [105., 128.]]])

# %%
div_tensor = tensor1 / tensor2
print(div_tensor)
# Out:
# tensor([[[0.1111, 0.2000],
#          [0.2727, 0.3333]],
#
#         [[0.3846, 0.4286],
#          [0.4667, 0.5000]]])

# %% [markdown]
# * 텐서 간 텐서곱 연산에서 두 텐서의 모양이 [2 x 2 x 2]이기 때문에 행렬 곱 연산이 가능

# %%
torch.add(tensor1, tensor2)
# Out:
# tensor([[[10., 12.],
#          [14., 16.]],
#
#         [[18., 20.],
#          [22., 24.]]])

# %%
torch.sub(tensor1, tensor2)
# Out:
# tensor([[[-8., -8.],
#          [-8., -8.]],
#
#         [[-8., -8.],
#          [-8., -8.]]])

# %%
torch.mul(tensor1, tensor2)
# Out:
# tensor([[[  9.,  20.],
#          [ 33.,  48.]],
#
#         [[ 65.,  84.],
#          [105., 128.]]])

# %%
torch.div(tensor1, tensor2)
# Out:
# tensor([[[0.1111, 0.2000],
#          [0.2727, 0.3333]],
#
#         [[0.3846, 0.4286],
#          [0.4667, 0.5000]]])

# %%
torch.matmul(tensor1, tensor2)
# Out:
# tensor([[[ 31.,  34.],
#          [ 71.,  78.]],
#
#         [[155., 166.],
#          [211., 226.]]])

# %%
tensor1
# Out:
# tensor([[[1., 2.],
#          [3., 4.]],
#
#         [[5., 6.],
#          [7., 8.]]])

# %%
tensor2
# Out:
# tensor([[[ 9., 10.],
#          [11., 12.]],
#
#         [[13., 14.],
#          [15., 16.]]])

# %% [markdown]
# ![image.png](attachment:dae91af6-0325-4652-99ab-552becc832d1.png)

# %%
torch.matmul(tensor1, tensor2)
# Out:
# tensor([[[ 31.,  34.],
#          [ 71.,  78.]],
#
#         [[155., 166.],
#          [211., 226.]]])

# %% [markdown]
# ## Autograd
# * 파이토치를 이용해 코드를 작성할 때 Back Propagation을 이용해 파라미터를 업데이터하는 방법은 Autograd 방식으로 쉽게 구현할 수 있도록 설정되어 있음
# * cuda.is_available()은 현재 파이썬이 실행되고 있는 환경에서 torch module을 이용할 때 GPU를 이용해 계산할 수 있는 파악하는 메서드임
#     * True : 사용할 수 있음
#     * False : 사용할 수 없음

# %%
import torch

if torch.cuda.is_available():
    DEVICE = torch.device('cuda')
else:
    DEVICE = torch.device('cpu')

# %%
DEVICE
# Out:
# device(type='cuda')

# %% [markdown]
# * OUTPUT_SIZE : 최종으로 출력되는 값의 벡터의 크기
#     * 레이블의 크기와 동일하게 설정

# %%
BATCH_SIZE = 64
INPUT_SIZE = 1000
HIDDEN_SIZE = 100
OUTPUT_SIZE = 10

# %% [markdown]
# * randn은 평균이 0, 표준편차가 1인 정규분포에서 샘플링한 값
# * 크기가 1000짜리의 벡터를 64개를 만들기 위해서 BATCH_SIZE는 64, INPUT_SIZE는 1000으로 설정
# * Input으로 이용되기 때문에 Gradient를 계산할 필요가 없기 때문에 requires_grad = False로 설정
# * w1은 Input의 데이터 크기가 1000이며 이와 행렬 곱을 하기 위해 다음 행의 값이 1000이어야 함
#     * 또한 행렬 곱을 이용해 100 크기의 데이터를 생성하기 위해 (1000, 100) 크기의 데이터를 생성
#     * requires_grad = True를 이용해 Gradient를 계산할 수 있도록 설정
# * w2도 역시 * requires_grad = True를 이용해 Gradient를 계산할 수 있도록 설정

# %%
x = torch.randn(BATCH_SIZE, 
                INPUT_SIZE, 
                device = DEVICE, 
                dtype = torch.float, 
                requires_grad = False)  

y = torch.randn(BATCH_SIZE, 
                OUTPUT_SIZE, 
                device = DEVICE,
                dtype = torch.float, 
                requires_grad = False)  

w1 = torch.randn(INPUT_SIZE, 
                 HIDDEN_SIZE, 
                 device = DEVICE, 
                 dtype = torch.float,
                 requires_grad = True)  

w2 = torch.randn(HIDDEN_SIZE,
                 OUTPUT_SIZE, 
                 device = DEVICE,
                 dtype = torch.float,
                 requires_grad = True)

# %% [markdown]
# * 파라미터를 업데이트할 때, Gradient를 계산한 결괏값에 1보다 작은 값을 곱해 업데이트합니다.
#     * Learning rate를 어떻게 설정하느냐에 따라 Gradient 값에 따른 학습 정도가 결정
# * 500번 반복해 파라미터 값을 업데이트하기 위해서 반복만 실행
# * 딥러닝 모델의 Input인 x와 Parameter w1간의 행렬 곱을 이용해 나온 결과값을 계산
#     * 그 이후 torch 모듈 내 clamp라는 메서드를 이용해 비선형 함수를 적용
#     * 딥러닝 모델에서는 층과 층 사이에 비선형 함수를 이용해 높은 표현력을 지니는 방정식을 얻게 됨
#     * clamp를 이용해 계산된 결과와 w2를 이용해 행렬 곱을 한 번 더 계산
# * 예측값과 실제 레이블 값을 비교해 오차를 계산한 값을 loss 값이라고 함
#     * loss function, cost function이라고도 부름
#     * 실제 값과 예측값 차잇값을 계산한 후 제곱차의 합을 이용해 계산
# * 계산된 Loss 값에 대해 backward() 메서드를 이용해 각 파라미터 값에 대해 Gradient를 계산하고 이를 통해 Back Propagation을 진행한다는 의미
# * with 구문은 각 파라미터 값에 대해 Gradient를 계산한 결과를 이용해 파라미터 값을 업데이트할 때는 해당 시점의 Gradient 값을 고정한 후 업데이트를 진행
#     * with 구문이 실행되는 시점에서 Gradient 값을 고정한다는 의미
# * 고정한 상태에서 w1의 Gradient 값을 learning rate 값을 곱한 결괏값을 기존으 w1에서 빼줌
#     * 음수를 이용하는 이유는 Loss 값이 최소로 계산될 수 있는 파라미터 값을 찾기 위해 Gradient 값에 대한 반대 방향으로 계산한다는 것을 의미
# * 마지막으로 Gradient 값을 0으로 초기화하여 다음 loop에서 계산된 값으로 다시 계산

# %%
learning_rate = 1e-6                                           
for t in range(1, 501):                                        
    y_pred = x.mm(w1).clamp(min = 0).mm(w2)                    

    loss = (y_pred - y).pow(2).sum()                          
    if t % 100 == 0:
        print("Iteration: ", t, "\t", "Loss: ", loss.item()) 
    loss.backward()                                           

    with torch.no_grad():                                      
        w1 -= learning_rate * w1.grad                          
        w2 -= learning_rate * w2.grad                          

        w1.grad.zero_()                                      
        w2.grad.zero_()
# Out:
# Iteration:  100 	 Loss:  1037.2613525390625
# Iteration:  200 	 Loss:  30.039440155029297
# Iteration:  300 	 Loss:  7.8872833251953125
# Iteration:  400 	 Loss:  11.92959976196289
# Iteration:  500 	 Loss:  11.753140449523926
